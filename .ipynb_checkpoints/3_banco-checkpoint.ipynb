# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import chardet

# Specify relative path to the file
file_path = "../IAPS/banco_completo.csv"

# Detect the encoding of the file
with open(file_path, 'rb') as f:
    result = chardet.detect(f.read())
    file_encoding = result['encoding']

# Load data into a pandas DataFrame with the correct encoding and delimiter specified
daf = pd.read_csv(file_path, encoding=file_encoding, delimiter=';')

# %%
occurrences = daf['estabel_saude'].value_counts()

print(occurrences)
# Out:
# HOSPITAL DO CANCER DE MURIAE                                   414
# HOSPITAL MARIA JOSE BAETA REIS ASCOMCER                        302
# ASSOCIACAO MARIO PENNA                                         298
# FUNDACAO PIO XII BARRETOS                                      293
# HOSPITAL DE CLINICAS DE UBERLANDIA                             287
# HOSPITAL DOUTOR HELIO ANGOTTI                                  276
# SANTA CASA DE BELO HORIZONTE                                   239
# HOSPITAL BOM PASTOR                                            230
# HOSPITAL SAO JOAO DE DEUS                                      216
# SANTA CASA DE MISERICORDIA DE PASSOS                           201
# HOSPITAL DAS CLINICAS DA UFMG                                  193
# HOSPITAL DA BALEIA                                             176
# HOSPITAL MARCIO CUNHA                                          175
# COMPLEXO HOSPITALAR SAO FRANCISCO                              139
# ...

# %%
import pandas as pd

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Create a new column 'is_santa_casa' to differentiate the rows
daf['is_santa_casa'] = daf['estabel_saude'].apply(lambda x: x == 'SANTA CASA DE BELO HORIZONTE')

# Separate rows based on 'is_santa_casa' value
santa_casa_rows = daf[daf['is_santa_casa']]
not_santa_casa_rows = daf[~daf['is_santa_casa']]

# Print the separated DataFrames or perform any other operations as needed
print("Rows with 'estabel_saude' being 'SANTA CASA DE BELO HORIZONTE':")
print(santa_casa_rows)

print("\nRows with 'estabel_saude' not being 'SANTA CASA DE BELO HORIZONTE':")
print(not_santa_casa_rows)
# Out:
# Rows with 'estabel_saude' being 'SANTA CASA DE BELO HORIZONTE':
#              ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  \
# 0         62980  02/05/1957    M        3  22/12/2014     C349        1
# 7       1556201  29/09/1942    M        3  16/06/2011     C780        1
# 16      3014470  11/08/1954    F        2  01/05/2015     K922        2
# 29      5682620  20/01/1962    F        3         NaN      NaN        3
# 65     13845301  20/03/1952    M        3  21/03/2015     C349        2
# ...         ...         ...  ...      ...         ...      ...      ...
# 4721  986359201  22/07/1960    F       99  14/11/2010     C349        2
# 4723  986649550  29/05/1956    F       99         NaN      NaN        3
# 4739  989210911  24/05/1955    M        3  19/07/2013     C349        1
# 4760  992208830  31/10/1966    F        2         NaN      NaN        2
# 4770  993504341  01/07/1954    M       99  28/04/2010     C349        1
#
# ...

# %%
santa_casa_rows
# Out:
#              ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  \
# 0         62980  02/05/1957    M        3  22/12/2014     C349        1
# 7       1556201  29/09/1942    M        3  16/06/2011     C780        1
# 16      3014470  11/08/1954    F        2  01/05/2015     K922        2
# 29      5682620  20/01/1962    F        3         NaN      NaN        3
# 65     13845301  20/03/1952    M        3  21/03/2015     C349        2
# ...         ...         ...  ...      ...         ...      ...      ...
# 4721  986359201  22/07/1960    F       99  14/11/2010     C349        2
# 4723  986649550  29/05/1956    F       99         NaN      NaN        3
# 4739  989210911  24/05/1955    M        3  19/07/2013     C349        1
# 4760  992208830  31/10/1966    F        2         NaN      NaN        2
# 4770  993504341  01/07/1954    M       99  28/04/2010     C349        1
#
#       qt_aih  obito  obito_internacao  ... macro_pcn  \
# ...

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you already have 'santa_casa_rows' and 'not_santa_casa_rows' DataFrames

# Calculate the contingency table
contingency_table = pd.crosstab(index=daf['obito'], columns=daf['is_santa_casa'])

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 0.22261619276412425
# P-value: 0.6370537003428387
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[1412.78972646   74.21027354]
#  [3137.21027354  164.78972646]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Create a new column 'is_hospital_cancer_muriae' to differentiate the rows
daf['is_hospital_cancer_muriae'] = daf['estabel_saude'].apply(lambda x: x == 'HOSPITAL DO CANCER DE MURIAE')

# Separate rows based on 'is_hospital_cancer_muriae' value
hospital_cancer_muriae_rows = daf[daf['is_hospital_cancer_muriae']]
not_hospital_cancer_muriae_rows = daf[~daf['is_hospital_cancer_muriae']]

# Calculate the contingency table for 'obito' and 'is_hospital_cancer_muriae'
contingency_table = pd.crosstab(index=daf['obito'], columns=daf['is_hospital_cancer_muriae'])

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 2.437351084312322
# P-value: 0.11847614263040854
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[1358.45166005  128.54833995]
#  [3016.54833995  285.45166005]]

# %%
# Create a new column 'is_hospital_ascomcer' to differentiate the rows
daf['is_hospital_ascomcer'] = daf['estabel_saude'].apply(lambda x: x == 'HOSPITAL MARIA JOSE BAETA REIS ASCOMCER')

# Separate rows based on 'is_hospital_ascomcer' value
hospital_ascomcer_rows = daf[daf['is_hospital_ascomcer']]
not_hospital_ascomcer_rows = daf[~daf['is_hospital_ascomcer']]

# Calculate the contingency table for 'obito' and 'is_hospital_ascomcer'
contingency_table = pd.crosstab(index=daf['obito'], columns=daf['is_hospital_ascomcer'])

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 1.741773086692957
# P-value: 0.18691432167965355
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[1393.22802255   93.77197745]
#  [3093.77197745  208.22802255]]

# %%
# Create a new column 'is_hospital_ascomcer' to differentiate the rows
daf['is_hospital_ascomcer'] = daf['estabel_saude'].apply(lambda x: x == 'HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE')

# Separate rows based on 'is_hospital_ascomcer' value
hospital_ascomcer_rows = daf[daf['is_hospital_ascomcer']]
not_hospital_ascomcer_rows = daf[~daf['is_hospital_ascomcer']]

# Calculate the contingency table for 'obito' and 'is_hospital_ascomcer'
contingency_table = pd.crosstab(index=daf['obito'], columns=daf['is_hospital_ascomcer'])

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 4.2648541485462985
# P-value: 0.038908589291957035
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[1476.13238672   10.86761328]
#  [3277.86761328   24.13238672]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Get the unique values in the 'estabel_saude' column
unique_estabel_saude = daf['estabel_saude'].unique()

# Create a dictionary to store the results
p_values_dict = {}

# Iterate through the unique values and perform chi-square test for each one
for estabel_value in unique_estabel_saude:
    # Create a new column to differentiate the rows for the current 'estabel_value'
    daf[f'is_{estabel_value.replace(" ", "_").lower()}'] = daf['estabel_saude'].apply(lambda x: x == estabel_value)

    # Separate rows based on the current 'estabel_value' and 'obito'
    contingency_table = pd.crosstab(index=daf['obito'], columns=daf[f'is_{estabel_value.replace(" ", "_").lower()}'])

    # Perform the chi-square test
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)

    # Store the p-value in the dictionary
    p_values_dict[estabel_value] = p_value

# Find the unique values with p-value less than 0.05
significant_values = [value for value, p_value in p_values_dict.items() if p_value < 0.05]

# Print the significant values
print("Unique items in 'estabel_saude' with p-value < 0.05:")
print(significant_values)
# Out:
# Unique items in 'estabel_saude' with p-value < 0.05:
# ['HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE', 'HOSPITAL DOUTOR HELIO ANGOTTI', 'COMPLEXO HOSPITALAR SAO FRANCISCO', 'HOSPITAL ALBERTO CAVALCANTI', 'HOSPITAL DO CANCER', 'HOSPITAL NOSSA SENHORA DAS DORES', 'HOSPITAL JULIA KUBITSCHEK']

# %%
daf
# Out:
#              ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  \
# 0         62980  02/05/1957    M        3  22/12/2014     C349        1
# 1        402050  04/07/1960    M        1  06/06/2012     C349        2
# 2        605650  20/03/1950    M        1  14/10/2014     C349        2
# 3       1162820  07/06/1937    F        1  11/02/2014     C349        1
# 4       1279111  30/12/1939    M       99  21/03/2009     C349        4
# ...         ...         ...  ...      ...         ...      ...      ...
# 4784  999248701  01/08/1952    M        1         NaN      NaN        2
# 4785  999359850  30/07/1953    M        3  16/06/2013     C349        1
# 4786  999364940  27/08/1940    M        1  17/03/2009     C349        5
# 4787  999442190  12/02/1937    M        1  12/02/2014     C349        4
# 4788  999673890  29/09/1941    M        1  09/12/2014     C349        1
#
#       qt_aih  obito  obito_internacao  ...  \
# 0          4      1               1.0  ...
# ...

# %%
import pandas as pd

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# List of selected 'estabel_saude' values
selected_estabel_saude = ['HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE',
                          'HOSPITAL DOUTOR HELIO ANGOTTI',
                          'COMPLEXO HOSPITALAR SAO FRANCISCO',
                          'HOSPITAL ALBERTO CAVALCANTI',
                          'HOSPITAL DO CANCER',
                          'HOSPITAL NOSSA SENHORA DAS DORES',
                          'HOSPITAL JULIA KUBITSCHEK']

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['estabel_saude', 'total_patients', 'obito_1_patients', 'obito_0_patients'])

# Iterate through the selected 'estabel_saude' values
for estabel_value in selected_estabel_saude:
    # Filter the DataFrame for the current 'estabel_value' and 'obito' values
    df_filtered = daf[daf['estabel_saude'] == estabel_value]

    # Calculate the total quantity of patients and the quantity of patients with obito == 1
    total_patients = len(df_filtered)
    patients_with_obito_1 = df_filtered['obito'].sum()

    # Calculate the quantity of patients with obito == 0
    patients_with_obito_0 = total_patients - patients_with_obito_1

    # Append the results to the DataFrame
    results_df = results_df.append({'estabel_saude': estabel_value,
                                    'total_patients': total_patients,
                                    'obito_1_patients': patients_with_obito_1,
                                    'obito_0_patients': patients_with_obito_0}, ignore_index=True)

# Print the results
print(results_df)
# Out:
#                                    estabel_saude total_patients  \
# 0  HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE             35
# 1                  HOSPITAL DOUTOR HELIO ANGOTTI            276
# 2              COMPLEXO HOSPITALAR SAO FRANCISCO            139
# 3                    HOSPITAL ALBERTO CAVALCANTI             93
# 4                             HOSPITAL DO CANCER             29
# 5               HOSPITAL NOSSA SENHORA DAS DORES             47
# 6                      HOSPITAL JULIA KUBITSCHEK             23
#
#   obito_1_patients obito_0_patients
# 0               18               17
# 1              212               64
# 2               74               65
# 3               50               43
# 4               27                2
# 5               22               25
# 6               10               13
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# List of selected 'estabel_saude' values
selected_estabel_saude = ['HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE',
                          'HOSPITAL DOUTOR HELIO ANGOTTI',
                          'COMPLEXO HOSPITALAR SAO FRANCISCO',
                          'HOSPITAL ALBERTO CAVALCANTI',
                          'HOSPITAL DO CANCER',
                          'HOSPITAL NOSSA SENHORA DAS DORES',
                          'HOSPITAL JULIA KUBITSCHEK']

# Calculate the total number of patients for the entire dataset
total_patients_all = len(daf)

# Print the total number of patients for the entire dataset
print("Total number of patients (entire dataset):", total_patients_all)

# Create a list to store the percentages of deaths for each hospital
death_percentages = []

# Iterate through the selected 'estabel_saude' values
for estabel_value in selected_estabel_saude:
    # Filter the DataFrame for the current 'estabel_value' and 'obito' values
    df_filtered = daf[daf['estabel_saude'] == estabel_value]

    # Calculate the total number of patients for the current hospital
    total_patients_hospital = len(df_filtered)

    # Calculate the number of patients with obito == 1 (died) for the current hospital
    patients_with_obito_1 = df_filtered['obito'].sum()

    # Calculate the percentage of deaths for the current hospital
    death_percentage = (patients_with_obito_1 / total_patients_hospital) * 100

    # Print the number of total patients and percentage of deaths for the current hospital
    print(f"Total number of patients ({estabel_value}):", total_patients_hospital)
    print(f"Percentage of deaths ({estabel_value}): {death_percentage:.2f}%")

    # Append the death percentage to the list
    death_percentages.append(death_percentage)

# Plot the percentages of deaths for each hospital
plt.figure(figsize=(10, 6))
plt.bar(['Entire Dataset'] + selected_estabel_saude, [total_patients_all] + death_percentages, color='blue')
plt.title("Percentage of Deaths")
plt.ylabel("Percentage")
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Total number of patients (entire dataset): 4789
# Total number of patients (HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE): 35
# Percentage of deaths (HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE): 51.43%
# Total number of patients (HOSPITAL DOUTOR HELIO ANGOTTI): 276
# Percentage of deaths (HOSPITAL DOUTOR HELIO ANGOTTI): 76.81%
# Total number of patients (COMPLEXO HOSPITALAR SAO FRANCISCO): 139
# Percentage of deaths (COMPLEXO HOSPITALAR SAO FRANCISCO): 53.24%
# Total number of patients (HOSPITAL ALBERTO CAVALCANTI): 93
# Percentage of deaths (HOSPITAL ALBERTO CAVALCANTI): 53.76%
# Total number of patients (HOSPITAL DO CANCER): 29
# Percentage of deaths (HOSPITAL DO CANCER): 93.10%
# Total number of patients (HOSPITAL NOSSA SENHORA DAS DORES): 47
# Percentage of deaths (HOSPITAL NOSSA SENHORA DAS DORES): 46.81%
# Total number of patients (HOSPITAL JULIA KUBITSCHEK): 23
# Percentage of deaths (HOSPITAL JULIA KUBITSCHEK): 43.48%

# %%
import pandas as pd

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Calculate the total number of patients for the entire dataset
total_patients_all = len(daf)

# Calculate the number of patients with obito == 1 (died) for the entire dataset
patients_with_obito_1_all = daf['obito'].sum()

# Calculate the overall percentage of deaths
overall_death_percentage = (patients_with_obito_1_all / total_patients_all) * 100

# Print the overall results
print("Total number of patients (entire dataset):", total_patients_all)
print("Total number of deaths (entire dataset):", patients_with_obito_1_all)
print("Overall Percentage of Deaths:", overall_death_percentage, "%")
# Out:
# Total number of patients (entire dataset): 4789
# Total number of deaths (entire dataset): 3302
# Overall Percentage of Deaths: 68.94967634161621 %

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Group the data by 'estabel_saude' and calculate the total number of patients and patients with obito == 1 (died)
grouped_df = daf.groupby('estabel_saude')['obito'].agg(total_patients='count', deaths='sum').reset_index()

# Calculate the percentage of deaths for each hospital
grouped_df['death_percentage'] = (grouped_df['deaths'] / grouped_df['total_patients']) * 100

# Sort the DataFrame based on the death_percentage in descending order
grouped_df = grouped_df.sort_values(by='death_percentage', ascending=False)

# Plot the percentages of deaths for each hospital
plt.figure(figsize=(10, 6))
plt.bar(grouped_df['estabel_saude'], grouped_df['death_percentage'], color='blue')
plt.title("Percentage of Deaths for Each Hospital")
plt.xlabel("Hospital ('estabel_saude')")
plt.ylabel("Percentage of Deaths")
plt.xticks(rotation=90, ha='center')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# List of selected 'estabel_saude' values
selected_estabel_saude = ['HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE',
                          'HOSPITAL DOUTOR HELIO ANGOTTI',
                          'COMPLEXO HOSPITALAR SAO FRANCISCO',
                          'HOSPITAL ALBERTO CAVALCANTI',
                          'HOSPITAL DO CANCER',
                          'HOSPITAL NOSSA SENHORA DAS DORES',
                          'HOSPITAL JULIA KUBITSCHEK']

# Calculate the total number of patients for the entire dataset
total_patients_all = len(daf)

# Print the total number of patients for the entire dataset
print("Total number of patients (entire dataset):", total_patients_all)

# Create a list to store the percentages of deaths for each hospital
death_percentages_hospitals = []

# Iterate through the selected 'estabel_saude' values
for estabel_value in selected_estabel_saude:
    # Filter the DataFrame for the current 'estabel_value' and 'obito' values
    df_filtered = daf[daf['estabel_saude'] == estabel_value]

    # Calculate the total number of patients for the current hospital
    total_patients_hospital = len(df_filtered)

    # Calculate the number of patients with obito == 1 (died) for the current hospital
    patients_with_obito_1 = df_filtered['obito'].sum()

    # Calculate the percentage of deaths for the current hospital
    death_percentage_hospital = (patients_with_obito_1 / total_patients_hospital) * 100

    # Print the number of total patients and percentage of deaths for the current hospital
    print(f"Total number of patients ({estabel_value}):", total_patients_hospital)
    print(f"Percentage of deaths ({estabel_value}): {death_percentage_hospital:.2f}%\n")

    # Append the death percentage to the list
    death_percentages_hospitals.append(death_percentage_hospital)

# Calculate the number of patients with obito == 1 (died) for the entire dataset
total_deaths_all = daf['obito'].sum()

# Calculate the percentage of deaths for the entire dataset
death_percentage_total = (total_deaths_all / total_patients_all) * 100

# Print the percentage of deaths for the entire dataset
print("Percentage of deaths (entire dataset):", death_percentage_total)

# Plot the percentages of deaths for each hospital along with the total percentage
plt.figure(figsize=(10, 6))
plt.bar(['Entire Dataset'] + selected_estabel_saude, [death_percentage_total] + death_percentages_hospitals, color='blue')
plt.title("Percentage of Deaths")
plt.ylabel("Percentage")
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Total number of patients (entire dataset): 4789
# Total number of patients (HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE): 35
# Percentage of deaths (HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE): 51.43%
#
# Total number of patients (HOSPITAL DOUTOR HELIO ANGOTTI): 276
# Percentage of deaths (HOSPITAL DOUTOR HELIO ANGOTTI): 76.81%
#
# Total number of patients (COMPLEXO HOSPITALAR SAO FRANCISCO): 139
# Percentage of deaths (COMPLEXO HOSPITALAR SAO FRANCISCO): 53.24%
#
# Total number of patients (HOSPITAL ALBERTO CAVALCANTI): 93
# Percentage of deaths (HOSPITAL ALBERTO CAVALCANTI): 53.76%
#
# Total number of patients (HOSPITAL DO CANCER): 29
# Percentage of deaths (HOSPITAL DO CANCER): 93.10%
#
# Total number of patients (HOSPITAL NOSSA SENHORA DAS DORES): 47
# Percentage of deaths (HOSPITAL NOSSA SENHORA DAS DORES): 46.81%
#
# Total number of patients (HOSPITAL JULIA KUBITSCHEK): 23
# Percentage of deaths (HOSPITAL JULIA KUBITSCHEK): 43.48%
#
# ...

# %%
import numpy as np

def cramers_v(confusion_matrix):
    """ calculate Cramers V statistic for categorial-categorial association. """
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1)))

# ... (your previous code up to for loop)

for estabel_value in unique_estabel_saude:
    # ... (your previous code inside the for loop)

    # Perform the chi-square test
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)

    # Calculate Cramer's V
    cramers_v_value = cramers_v(contingency_table)

    # Store the p-value and Cramer's V in the dictionary
    p_values_dict[estabel_value] = {"p_value": p_value, "cramers_v": cramers_v_value}

# ... (your previous code after the for loop)

# Print the significant values and their corresponding Cramer's V
print("Unique items in 'estabel_saude' with p-value < 0.05 and their Cramer's V:")
for value, stats in p_values_dict.items():
    if stats["p_value"] < 0.05:
        print(f"{value}: Cramer's V = {stats['cramers_v']}")
# Out:
# Unique items in 'estabel_saude' with p-value < 0.05 and their Cramer's V:
# SANTA CASA DE BELO HORIZONTE: Cramer's V = 0.026112048241826617
# FUNDACAO PIO XII BARRETOS: Cramer's V = 0.026112048241826617
# ASSOCIACAO MARIO PENNA: Cramer's V = 0.026112048241826617
# HOSPITAL FELICIO ROCHO: Cramer's V = 0.026112048241826617
# HOSPITAL MARIA JOSE BAETA REIS ASCOMCER: Cramer's V = 0.026112048241826617
# HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE: Cramer's V = 0.026112048241826617
# HOSPITAL DOUTOR HELIO ANGOTTI: Cramer's V = 0.026112048241826617
# COMPLEXO HOSPITALAR SAO FRANCISCO: Cramer's V = 0.026112048241826617
# HOSPITAL SANTA CASA DE MONTES CLAROS: Cramer's V = 0.026112048241826617
# HOSPITAL ALBERTO CAVALCANTI: Cramer's V = 0.026112048241826617
# HOSPITAL DO CANCER: Cramer's V = 0.026112048241826617
# SANTA CASA DA MISERICORDIA DE SAO JOAO DEL REI: Cramer's V = 0.026112048241826617
# HOSPITAL BOM PASTOR: Cramer's V = 0.026112048241826617
# ...

# %%
df=daf.copy()

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Assuming you already have 'df' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Get the unique values in the 'estabel_saude' column
unique_estabel_saude = df['estabel_saude'].unique()

# Create a dictionary to store the results
p_values_dict = {}
cramers_v_dict = {}

# Define a function for Cramer's V
def cramers_v(chi2, n, shape):
    return np.sqrt(chi2 / (n*(min(shape)-1)))

# Iterate through the unique values and perform chi-square test for each one
for estabel_value in unique_estabel_saude:
    # Create a new DataFrame for the current 'estabel_value'
    df_temp = df[df['estabel_saude'] == estabel_value]

    # Separate rows based on the current 'estabel_value' and 'obito'
    contingency_table = pd.crosstab(index=df_temp['obito'], columns=df_temp['estabel_saude'])

    # Perform the chi-square test
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)

    # Store the p-value in the dictionary
    p_values_dict[estabel_value] = p_value

    # Calculate and store Cramer's V in the dictionary
    if p_value < 0.05:
        cramers_v_dict[estabel_value] = cramers_v(chi2, len(df_temp), contingency_table.shape)

# Print the significant values and their Cramér's V
for key in cramers_v_dict:
    print(f"{key}: Cramer's V = {cramers_v_dict[key]}")

# %%
print(p_values_dict)
# Out:
# {'SANTA CASA DE BELO HORIZONTE': 1.0, 'FUNDACAO PIO XII BARRETOS': 1.0, 'ASSOCIACAO MARIO PENNA': 1.0, 'HOSPITAL FELICIO ROCHO': 1.0, 'HOSPITAL MARIA JOSE BAETA REIS ASCOMCER': 1.0, 'HOSPITAL DAS CLIN SAMUEL LIBANIO POUSO ALEGRE': 1.0, 'HOSPITAL DOUTOR HELIO ANGOTTI': 1.0, 'COMPLEXO HOSPITALAR SAO FRANCISCO': 1.0, 'HOSPITAL SANTA CASA DE MONTES CLAROS': 1.0, 'HOSPITAL ALBERTO CAVALCANTI': 1.0, 'HOSPITAL DO CANCER': 1.0, 'SANTA CASA DA MISERICORDIA DE SAO JOAO DEL REI': 1.0, 'HOSPITAL BOM PASTOR': 1.0, 'IRMANDADE DA SANTA CASA DE MISERICORDIA DE CATAGUASES': 1.0, 'HOSPITAL BOM SAMARITANO': 1.0, 'HOSPITAL DO CANCER DE MURIAE': 1.0, 'HOSPITAL SAO JOAO DE DEUS': 1.0, 'HOSPITAL MARCIO CUNHA': 1.0, 'HOSPITAL DE CLINICAS DE UBERLANDIA': 1.0, 'HOSPITAL DA BALEIA': 1.0, 'HOSPITAL NOSSA SENHORA DAS GRACAS': 1.0, 'SANTA CASA DE ALFENAS': 1.0, 'HOSPITAL DAS CLINICAS DA UFMG': 1.0, 'HOSPITAL DILSON GODINHO': 1.0, 'HOSPITAL IBIAPABA CEBAMS': 1.0, 'SANTA CASA DE MISERICORDIA DE PASSOS': 1.0, 'SANTA
# ...
