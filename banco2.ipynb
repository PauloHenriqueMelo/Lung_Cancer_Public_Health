# %%
import pandas as pd
import chardet

# Specify relative path to the file
file_path = "../IAPS/banco_completo.csv"

# Detect the encoding of the file
with open(file_path, 'rb') as f:
    result = chardet.detect(f.read())
    file_encoding = result['encoding']

# Load data into a pandas DataFrame with the correct encoding and delimiter specified
daf = pd.read_csv(file_path, encoding=file_encoding, delimiter=';')

# Print basic information about the DataFrame
print(daf.info())

# Or display the first few rows of the DataFrame
print(daf.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4789 entries, 0 to 4788
# Data columns (total 50 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          4789 non-null   int64
#  1   dt_nasc                     4789 non-null   object
#  2   sexo                        4789 non-null   object
#  3   racacor                     4789 non-null   int64
#  4   dt_obito                    3302 non-null   object
#  5   causabas                    3302 non-null   object
#  6   qt_apac                     4789 non-null   int64
#  7   qt_aih                      4789 non-null   int64
#  8   obito                       4789 non-null   int64
#  9   obito_internacao            2034 non-null   float64
#  10  dt_diag                     4789 non-null   object
#  11  estadio                     4789 non-null   int64
#  12  dt_proc_min                 4789 non-null   object
#  13  idade                       4789 non-null   int64
#  14  tipo_proc_min               4789 non-null   int64
#  15  cidpri_min                  4789 non-null   object
#  16  dt_proc_max                 4789 non-null   object
#  17  proc_max                    4789 non-null   int64
#  18  n_comorb                    4789 non-null   int64
#  19  dt_tto_min                  4789 non-null   object
#  20  desc_f_org_tto_min          4789 non-null   object
#  21  cid_tto_min                 4785 non-null   object
#  22  tipo_tto_min                4789 non-null   int64
#  23  tempo_diag_tto_min          4789 non-null   int64
#  24  tempo_internacao            4789 non-null   int64
#  25  tempo_coorte                4789 non-null   int64
#  26  perfil                      4789 non-null   int64
#  27  estadio_rec                 4789 non-null   object
#  28  f_org_tto_min_rec           4789 non-null   object
#  29  perfil_rec                  4789 non-null   object
#  30  qt_obito_simaih             4789 non-null   int64
#  31  causabas_simaih_rec         3563 non-null   object
#  32  causabas_simaih_rec_agrup   3563 non-null   object
#  33  causabas_simaih_rec_agrup2  3563 non-null   object
#  34  cir_proc_tto_min_rec        119 non-null    object
#  35  cir_proc_tto_min_rec2       119 non-null    object
#  36  time_diag                   4789 non-null   object
#  37  cump_lei60dias              4789 non-null   int64
#  38  macro_tto                   4789 non-null   object
#  39  mun_pcn                     4789 non-null   object
#  40  regiao_pcn                  4789 non-null   object
#  41  macro_pcn                   4789 non-null   object
#  42  estabel_saude               4789 non-null   object
#  43  cidade_estabel              4789 non-null   object
#  44  estado_estabel              4789 non-null   object
#  45  regiao_estabel              4789 non-null   object
#  46  macro_estabel               4789 non-null   object
#  47  regiao_bras_estabel         4789 non-null   object
#  48  finaliquimio                3870 non-null   object
#  49  finaliradio                 800 non-null    object
# dtypes: float64(1), int64(17), object(32)
# memory usage: 1.8+ MB
# None
#         ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  qt_aih  \
# 0    62980  02/05/1957    M        3  22/12/2014     C349        1       4
# 1   402050  04/07/1960    M        1  06/06/2012     C349        2       2
# 2   605650  20/03/1950    M        1  14/10/2014     C349        2       8
# 3  1162820  07/06/1937    F        1  11/02/2014     C349        1       1
# 4  1279111  30/12/1939    M       99  21/03/2009     C349        4       1
#
#    obito  obito_internacao  ...      regiao_pcn         macro_pcn  \
# 0      1               1.0  ...  Belo Horizonte            Centro
# 1      1               1.0  ...         Frutal   Triângulo do Sul
# 2      1               1.0  ...  Belo Horizonte            Centro
# 3      1               NaN  ...    Sete Lagoas             Centro
# 4      1               1.0  ...    Juiz de Fora           Sudeste
#
#                              estabel_saude  cidade_estabel  estado_estabel  \
# 0             SANTA CASA DE BELO HORIZONTE  Belo Horizonte              MG
# 1                FUNDACAO PIO XII BARRETOS        BARRETOS              SP
# 2                   ASSOCIACAO MARIO PENNA  Belo Horizonte              MG
# 3                   HOSPITAL FELICIO ROCHO  Belo Horizonte              MG
# 4  HOSPITAL MARIA JOSE BAETA REIS ASCOMCER   Juiz de Fora               MG
#
#     regiao_estabel   macro_estabel  regiao_bras_estabel  finaliquimio  \
# 0   Belo Horizonte          Centro             Sudeste            NaN
# 1  Outros Estados   Outros Estados             Sudeste      Paliativa
# 2   Belo Horizonte          Centro             Sudeste         Demais
# 3   Belo Horizonte          Centro             Sudeste      Paliativa
# 4    Juiz de Fora          Sudeste             Sudeste         Demais
#
#   finaliradio
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 50 columns]

# %%
daf
# Out:
#              ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  \
# 0         62980  02/05/1957    M        3  22/12/2014     C349        1
# 1        402050  04/07/1960    M        1  06/06/2012     C349        2
# 2        605650  20/03/1950    M        1  14/10/2014     C349        2
# 3       1162820  07/06/1937    F        1  11/02/2014     C349        1
# 4       1279111  30/12/1939    M       99  21/03/2009     C349        4
# ...         ...         ...  ...      ...         ...      ...      ...
# 4784  999248701  01/08/1952    M        1         NaN      NaN        2
# 4785  999359850  30/07/1953    M        3  16/06/2013     C349        1
# 4786  999364940  27/08/1940    M        1  17/03/2009     C349        5
# 4787  999442190  12/02/1937    M        1  12/02/2014     C349        4
# 4788  999673890  29/09/1941    M        1  09/12/2014     C349        1
#
#       qt_aih  obito  obito_internacao  ...        regiao_pcn  \
# 0          4      1               1.0  ...    Belo Horizonte
# 1          2      1               1.0  ...           Frutal
# 2          8      1               1.0  ...    Belo Horizonte
# 3          1      1               NaN  ...      Sete Lagoas
# 4          1      1               1.0  ...      Juiz de Fora
# ...      ...    ...               ...  ...               ...
# 4784       0      0               NaN  ...          Uberaba
# 4785       2      1               NaN  ...               Ubá
# 4786       0      1               NaN  ...  Poços de Caldas
# 4787       3      1               1.0  ...       Ponte Nova
# 4788       2      1               1.0  ...          Guaxupé
#
#              macro_pcn                            estabel_saude  \
# 0               Centro             SANTA CASA DE BELO HORIZONTE
# 1     Triângulo do Sul                FUNDACAO PIO XII BARRETOS
# 2               Centro                   ASSOCIACAO MARIO PENNA
# 3               Centro                   HOSPITAL FELICIO ROCHO
# 4              Sudeste  HOSPITAL MARIA JOSE BAETA REIS ASCOMCER
# ...                ...                                      ...
# 4784  Triângulo do Sul            HOSPITAL DOUTOR HELIO ANGOTTI
# 4785           Sudeste             HOSPITAL DO CANCER DE MURIAE
# 4786               Sul                FUNDACAO PIO XII BARRETOS
# 4787      Leste do Sul                   HOSPITAL FELICIO ROCHO
# 4788               Sul     SANTA CASA DE MISERICORDIA DE PASSOS
#
#       cidade_estabel  estado_estabel   regiao_estabel     macro_estabel  \
# 0     Belo Horizonte              MG   Belo Horizonte            Centro
# 1           BARRETOS              SP  Outros Estados     Outros Estados
# 2     Belo Horizonte              MG   Belo Horizonte            Centro
# 3     Belo Horizonte              MG   Belo Horizonte            Centro
# 4      Juiz de Fora               MG    Juiz de Fora            Sudeste
# ...              ...             ...              ...               ...
# 4784        Uberaba               MG         Uberaba   Triângulo do Sul
# 4785         Muriaé               MG          Muriaé            Sudeste
# 4786        BARRETOS              SP  Outros Estados     Outros Estados
# 4787  Belo Horizonte              MG   Belo Horizonte            Centro
# 4788          Passos              MG          Passos                Sul
#
#       regiao_bras_estabel  finaliquimio finaliradio
# 0                Sudeste            NaN         NaN
# 1                Sudeste      Paliativa         NaN
# 2                Sudeste         Demais         NaN
# 3                Sudeste      Paliativa         NaN
# 4                Sudeste         Demais         NaN
# ...                   ...           ...         ...
# 4784             Sudeste      Paliativa         NaN
# 4785             Sudeste      Paliativa         NaN
# 4786             Sudeste         Demais         NaN
# 4787             Sudeste            NaN      Demais
# 4788             Sudeste      Paliativa         NaN
#
# [4789 rows x 50 columns]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you already have 'daf' DataFrame loaded from the CSV file using the correct encoding and delimiter

# Create a new column 'is_hospital_julia_kubitschek' to differentiate the rows
daf['is_hospital_julia_kubitschek'] = daf['estabel_saude'].apply(lambda x: x == 'HOSPITAL JULIA KUBITSCHEK')

# Separate rows based on 'is_hospital_julia_kubitschek' value
hospital_julia_kubitschek_rows = daf[daf['is_hospital_julia_kubitschek']]
not_hospital_julia_kubitschek_rows = daf[~daf['is_hospital_julia_kubitschek']]

# Calculate the contingency table for 'obito' and 'is_hospital_julia_kubitschek'
contingency_table = pd.crosstab(index=daf['obito'], columns=daf['is_hospital_julia_kubitschek'])

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 5.859209179748884
# P-value: 0.01549575477027298
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[1479.85842556    7.14157444]
#  [3286.14157444   15.85842556]]

# %%
print((hospital_julia_kubitschek_rows['obito']==1).sum())
print((hospital_julia_kubitschek_rows['obito']==0).sum())
print((not_hospital_julia_kubitschek_rows['obito']==1).sum())
print((not_hospital_julia_kubitschek_rows['obito']==0).sum())
# Out:
# 10
# 13
# 3292
# 1474

# %%
hospital_julia_kubitschek_rows
# Out:
#              ID     dt_nasc sexo  racacor    dt_obito causabas  qt_apac  \
# 401    91831030  15/03/1960    F       99         NaN      NaN        3
# 452   101571811  18/02/1941    M       99         NaN      NaN        2
# 613   129661631  19/05/1940    M       99         NaN      NaN        1
# 734   153903230  05/07/1951    M       99  20/09/2012     C349        2
# 990   203597870  23/10/1948    F       99  17/03/2015     C349       11
# 1168  242023211  11/07/1952    M        3  29/04/2015     C349        2
# 1694  355887670  06/10/1930    F       99         NaN      NaN        3
# 1780  374566470  17/02/1961    M       99         NaN      NaN        2
# 1833  384251680  14/11/1951    M       99  24/07/2013     C349        2
# 1971  416595880  12/10/1965    M        3  10/01/2013     C349        2
# 2451  516724450  26/07/1933    M       99  16/06/2012     C349        8
# 2662  560154650  24/05/1962    F        2         NaN      NaN        7
# 3147  658642270  14/05/1958    M        3         NaN      NaN        5
# 3612  759262701  23/12/1955    M        3  31/03/2014     C349        2
# 3627  761724930  12/03/1947    F       99         NaN      NaN        2
# 3633  762541650  01/04/1950    F        4         NaN      NaN        2
# 3654  765405650  06/12/1938    F        1  20/07/2014     C349        1
# 3660  766205590  19/12/1961    F       99         NaN      NaN        4
# 3904  813650350  17/11/1949    F        3         NaN      NaN        1
# 3946  822587380  06/03/1964    M        1         NaN      NaN        6
# 4010  834533130  16/09/1942    M       99         NaN      NaN        2
# 4063  844890090  11/03/1962    M       99  20/08/2014     C340        2
# 4672  975099510  28/12/1947    F        3  08/11/2008     C349        1
#
#       qt_aih  obito  obito_internacao  ...     macro_pcn  \
# 401        5      0               NaN  ...        Centro
# 452        1      0               NaN  ...        Centro
# 613        5      0               NaN  ...         Leste
# 734        3      1               1.0  ...        Centro
# 990        1      1               NaN  ...        Centro
# 1168       5      1               1.0  ...  Leste do Sul
# 1694       1      0               NaN  ...        Centro
# 1780       1      0               NaN  ...        Centro
# 1833       2      1               1.0  ...        Centro
# 1971       5      1               1.0  ...         Oeste
# 2451       2      1               NaN  ...  Leste do Sul
# 2662       1      0               NaN  ...        Centro
# 3147       6      0               NaN  ...        Centro
# 3612       2      1               1.0  ...        Centro
# 3627       1      0               NaN  ...        Centro
# 3633       2      0               NaN  ...        Centro
# 3654       1      1               NaN  ...        Centro
# 3660       3      0               NaN  ...         Leste
# 3904       2      0               NaN  ...        Centro
# 3946       6      0               1.0  ...         Leste
# 4010       1      0               NaN  ...         Oeste
# 4063       1      1               NaN  ...        Centro
# 4672       4      1               1.0  ...        Centro
#
#                   estabel_saude  cidade_estabel  estado_estabel  \
# 401   HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 452   HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 613   HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 734   HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 990   HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 1168  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 1694  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 1780  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 1833  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 1971  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 2451  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 2662  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3147  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3612  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3627  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3633  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3654  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3660  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3904  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 3946  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 4010  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 4063  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
# 4672  HOSPITAL JULIA KUBITSCHEK  Belo Horizonte              MG
#
#       regiao_estabel macro_estabel regiao_bras_estabel  finaliquimio  \
# 401   Belo Horizonte        Centro            Sudeste            NaN
# 452   Belo Horizonte        Centro            Sudeste            NaN
# 613   Belo Horizonte        Centro            Sudeste            NaN
# 734   Belo Horizonte        Centro            Sudeste            NaN
# 990   Belo Horizonte        Centro            Sudeste            NaN
# 1168  Belo Horizonte        Centro            Sudeste            NaN
# 1694  Belo Horizonte        Centro            Sudeste            NaN
# 1780  Belo Horizonte        Centro            Sudeste            NaN
# 1833  Belo Horizonte        Centro            Sudeste            NaN
# 1971  Belo Horizonte        Centro            Sudeste            NaN
# 2451  Belo Horizonte        Centro            Sudeste            NaN
# 2662  Belo Horizonte        Centro            Sudeste            NaN
# 3147  Belo Horizonte        Centro            Sudeste            NaN
# 3612  Belo Horizonte        Centro            Sudeste            NaN
# 3627  Belo Horizonte        Centro            Sudeste            NaN
# 3633  Belo Horizonte        Centro            Sudeste            NaN
# 3654  Belo Horizonte        Centro            Sudeste            NaN
# 3660  Belo Horizonte        Centro            Sudeste            NaN
# 3904  Belo Horizonte        Centro            Sudeste            NaN
# 3946  Belo Horizonte        Centro            Sudeste            NaN
# 4010  Belo Horizonte        Centro            Sudeste            NaN
# 4063  Belo Horizonte        Centro            Sudeste            NaN
# 4672  Belo Horizonte        Centro            Sudeste            NaN
#
#       finaliradio is_hospital_julia_kubitschek
# 401           NaN                         True
# 452           NaN                         True
# 613           NaN                         True
# 734           NaN                         True
# 990           NaN                         True
# 1168          NaN                         True
# 1694          NaN                         True
# 1780          NaN                         True
# 1833          NaN                         True
# 1971          NaN                         True
# 2451          NaN                         True
# 2662          NaN                         True
# 3147          NaN                         True
# 3612          NaN                         True
# 3627          NaN                         True
# 3633          NaN                         True
# 3654          NaN                         True
# 3660          NaN                         True
# 3904          NaN                         True
# 3946          NaN                         True
# 4010          NaN                         True
# 4063          NaN                         True
# 4672          NaN                         True
#
# [23 rows x 51 columns]
